# %%
f= open("guru99.txt","w+")
for i in range(10):
     f.write("This is line %d\r\n" % (i+1))
f.close()

# %%
fls = []
for j in range(10):
    x=[]
    for i in range(10):
        s = "_SubServer0" + str(i) + "File_0" + str(j) + ".txt"
        x.append(s)
    fls.append(x)

# %%
for serv in fls:
    for fl in serv:
        f= open(fl,"w+")
        for i in range(10):
             f.write("This is line %d\r\n" % (i+1))
        f.close() 
        print(fl)
    print("\n \n")
# Out:
# _SubServer00File_00.txt
# _SubServer01File_00.txt
# _SubServer02File_00.txt
# _SubServer03File_00.txt
# _SubServer04File_00.txt
# _SubServer05File_00.txt
# _SubServer06File_00.txt
# _SubServer07File_00.txt
# _SubServer08File_00.txt
# _SubServer09File_00.txt
#
#
#
# _SubServer00File_01.txt
# _SubServer01File_01.txt
# _SubServer02File_01.txt
# _SubServer03File_01.txt
# _SubServer04File_01.txt
# _SubServer05File_01.txt
# _SubServer06File_01.txt
# _SubServer07File_01.txt
# _SubServer08File_01.txt
# _SubServer09File_01.txt
#
#
#
# _SubServer00File_02.txt
# _SubServer01File_02.txt
# _SubServer02File_02.txt
# _SubServer03File_02.txt
# _SubServer04File_02.txt
# _SubServer05File_02.txt
# _SubServer06File_02.txt
# _SubServer07File_02.txt
# _SubServer08File_02.txt
# _SubServer09File_02.txt
#
#
#
# _SubServer00File_03.txt
# _SubServer01File_03.txt
# _SubServer02File_03.txt
# _SubServer03File_03.txt
# _SubServer04File_03.txt
# _SubServer05File_03.txt
# _SubServer06File_03.txt
# ...
